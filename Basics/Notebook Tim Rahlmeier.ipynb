# %%
import sys
sys.version
# Out:
# '3.6.9 (default, Jul 17 2020, 12:50:27) \n[GCC 8.4.0]'

# %%
import pandas as pd
print(pd.__version__)
#leider ist das schon die neueste Version
# Eine andere Version könnte man aber z.B. mit !pip install pandas== x.xx.xx installieren
# Oder generell: !pip install --upgrade pandas automatisch nach einer neuen Version schauen.
# Out:
# 1.1.2

# %%
from IPython.display import HTML

# Youtube
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/XZysgIslP2A" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/XZysgIslP2A" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
